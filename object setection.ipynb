# %% [markdown]
# # Deep Dive into Object Detection

# %%
def calculate_iou(box1, box2):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.
    Box format: [x_min, y_min, x_max, y_max]
    """

    x_left = max(box1[0], box2[0])
    y_top = max(box1[1], box2[1])

    return 0.0

box_A = [50, 50, 150, 150]
box_B = [100, 100, 200, 200]
box_C = [200, 200, 300, 300]

iou_AB = calculate_iou(box_A, box_B)
iou_AC = calculate_iou(box_A, box_C)

print(f"IoU between Box A and Box B: {iou_AB:.3f}")
print(f"IoU between Box A and Box C: {iou_AC:.3f}")
# Out:
# IoU between Box A and Box B: 0.000
# IoU between Box A and Box C: 0.000

# %%
# !pip install ultralytics -q
from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

print("Processing video...")
results = model.predict(source=video, save=True, conf=0.25)
# Out:
# Processing video...
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 10.7ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 7.6ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.0ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.0ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.1ms
# ...

# %%
def calculate_iou(box1, box2):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.
    Box format: [x_min, y_min, x_max, y_max]
    """

    x_left = max(box1[0], box2[0])
    y_top = max(box1[1], box2[1])
    x_right = min(box1[2], box2[2])
    y_bottom = min(box1[3], box2[3])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])

    union_area = box1_area + box2_area - intersection_area

    if union_area == 0:
        return 0.0
    iou = intersection_area / union_area
    return iou

box_A = [50, 50, 150, 150]
box_B = [100, 100, 200, 200]
box_C = [200, 200, 300, 300]

iou_AB = calculate_iou(box_A, box_B)
iou_AC = calculate_iou(box_A, box_C)

print(f"IoU between Box A and Box B: {iou_AB:.3f}")
print(f"IoU between Box A and Box C: {iou_AC:.3f}")
# Out:
# IoU between Box A and Box B: 0.143
# IoU between Box A and Box C: 0.000

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

print("Processing video...")
results = model.predict(source=video, save=True, conf=0.25)
# Out:
# Processing video...
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.7ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.4ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.2ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 5.8ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.0ms
# ...

# %%
print("Installing...")
# !pip install ultralytics -q
print("Installed.")
# Out:
# Installing...
# Installed.

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

print("Processing video...")
results = model.predict(source=video, save=True, conf=0.25)
# Out:
# Processing video...
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.7ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.1ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.6ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.4ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.1ms
# ...

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

print("Processing video...")
results = model.predict(source=video, save=True, conf=0.25)
# Out:
# Processing video...
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.6ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.1ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.9ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.7ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.0ms
# ...

# %%
# !ls -F runs/detect/predict/
# Out:
# manu_vs_athletic.avi

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

print("Processing video...")
results = model.predict(source=video, save=True, conf=0.25)
# Out:
# Processing video...
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 8.5ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 8.2ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 7.7ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 7.8ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 8.0ms
# ...

# %%
print("...")
# !apt-get update -qq
# !apt-get install -y ffmpeg
# Out:
# ...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 88 not upgraded.

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

print("Processing video...")
results = model.predict(source=video, save=True, conf=0.25)
# Out:
# Processing video...
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 7.1ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.2ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.1ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.3ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 5.9ms
# ...

# %%
# !pip install ultralytics --upgrade -q

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

print("Processing video...")
results = model.predict(source=video, save=True, conf=0.25)
# Out:
# Processing video...
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 7.2ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.2ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 7.2ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.0ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 5.9ms
# ...

# %%
import os

# !pip install ultralytics opencv-python --upgrade -q

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

results = model.predict(source=video, save=True, conf=0.25)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.6ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 5.9ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.2ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.0ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 5.9ms
# ...

# %%
import os
import cv2

# !pip install ultralytics opencv-python --upgrade -q

video_path = '/content/manu_vs_athletic.mp4'
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"[DIAGNOSTIC ERROR] OpenCV FAILED to open video: {video_path}.")

    raise FileNotFoundError(f"Could not open video: {video_path}")
else:
    print(f"[DIAGNOSTIC SUCCESS] Successfully opened video: {video_path}. Proceeding with YOLO inference.")
    cap.release()

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

results = model.predict(source=video, save=True, conf=0.25)
# Out:
# [DIAGNOSTIC SUCCESS] Successfully opened video: /content/manu_vs_athletic.mp4. Proceeding with YOLO inference.
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.7ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.6ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.5ms
# ...

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')

results = model.predict(source=video, save=True, conf=0.25)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.6ms
# video 1/1 (frame 2/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.0ms
# video 1/1 (frame 3/78) /content/manu_vs_athletic.mp4: 384x640 19 persons, 6.9ms
# video 1/1 (frame 4/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.4ms
# video 1/1 (frame 5/78) /content/manu_vs_athletic.mp4: 384x640 18 persons, 6.7ms
# ...

# %%
import os

from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8n.pt')
results = model.predict(source=video, save=True, conf=0.25, stream=True)

# %%
import os
from ultralytics import YOLO

video = '/content/manu_vs_athletic.mp4'

model = YOLO('yolov8s.pt')

results = model.predict(source=video, save=True, conf=0.5, iou=0.5, stream=True)

# %%
# !ls -F runs/detect/predict/
# Out:
# manu_vs_athletic.avi
